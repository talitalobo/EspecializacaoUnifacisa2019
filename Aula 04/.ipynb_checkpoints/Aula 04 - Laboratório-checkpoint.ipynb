# %% [markdown]
# ## Aula 04: Experimentação prática
#
# ### Explorando os dados, construindo e interpretando grupos

# %% [markdown]
# # Quais as minhas variáveis?
#
# # Quais os tipos das variáveis?
#
# # Tenho valores faltantes ou nulos?
#
# # Interpretação do sumário
#
# # Qual pergunta desejo responder? Com base em quê desejo encontrar agrupamentos nos dados?
#
# # Qual a quantidade de grupos que devo utilizar?
#
# # Devo reduzir a quantidade de features?
#
# # Devo fazer scale nos dados?
#
# # Como posso interpretar os grupos gerados?
#
# # Indo além:
# a) Plotar o nome/código dos clientes nos pontos do gráfico
#
# b) Variar o número de grupos e verificar a saída
#
# c) Devo aplicar alguma transformação nos meus dados? (ex: log 2/10)
#
# d) Utilizar o K-Medians [ou outro método](https://scikit-learn.org/stable/modules/clustering.html) traria alguma novidade?
#
# e) Conseguimos calcular a matriz de distâncias, para o Algoritmo Hierárquico?

# %%
import pandas as pd # para criação do data frame

# %%
# Importando os dados 
clientes = pd.read_csv("ClientesShopping.csv")

# Exibindo as primeiras linhas do dado
clientes
# Out:
#      ClienteId  Genero  Idade  Renda(Milhares)  Credito
# 0            1    Male     19               15       39
# 1            2    Male     21               15       81
# 2            3  Female     20               16        6
# 3            4  Female     23               16       77
# 4            5  Female     31               17       40
# 5            6  Female     22               17       76
# 6            7  Female     35               18        6
# 7            8  Female     23               18       94
# 8            9    Male     64               19        3
# 9           10  Female     30               19       72
# 10          11    Male     67               19       14
# 11          12  Female     35               19       99
# 12          13  Female     58               20       15
# 13          14  Female     24               20       77
# 14          15    Male     37               20       13
# 15          16    Male     22               20       79
# ...

# %% [markdown]
# ### Dicionário de Dados

# %% [markdown]
# * `ClienteId`: Id de identificação do cliente
# * `Genero`: Gênero do comprador
# * `Idade`: Idade do comprador
# * `Renda(Milhares)`: Renda em milhares de reais
# * `Credito`: Crédito na praça (de 1 a 100)
